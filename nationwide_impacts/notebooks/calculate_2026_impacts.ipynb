# %%
from policyengine_us import Microsimulation
from policyengine_core.reforms import Reform
import pandas as pd
import numpy as np
from itertools import product

# %%
def generate_policy_combinations():
    # SALT configurations with explicit joint/non-joint amounts and phase-out parameters
    salt_configs = [
        {
            "name": "0_cap",
            "cap_joint": 0,
            "cap_other": 0,
            "phase_out": False,
            "phase_out_rate": 0,
            "phase_out_threshold_joint": 0,
            "phase_out_threshold_other": 0,
        },
        {
            "name": "tcja_base",
            "cap_joint": 10_000,
            "cap_other": 10_000,
            "phase_out": False,
            "phase_out_rate": 0,
            "phase_out_threshold_joint": 0,
            "phase_out_threshold_other": 0,
        },
        {
            "name": "tcja_base_with_married_bonus",
            "cap_joint": 20_000,
            "cap_other": 10_000,
            "phase_out": False,
            "phase_out_rate": 0,
            "phase_out_threshold_joint": 0,
            "phase_out_threshold_other": 0,
        },
        {
            "name": "tcja_base_with_phaseout",
            "cap_joint": 10_000,
            "cap_other": 10_000,
            "phase_out": True,
            "phase_out_rate": 0.1,  # 10%
            "phase_out_threshold_joint": 400_000,
            "phase_out_threshold_other": 200_000,
        },
        {
            "name": "tcja_married_bonus_and_phase_out",
            "cap_joint": 20_000,
            "cap_other": 10_000,
            "phase_out": True,
            "phase_out_rate": 0.1,  # 10%
            "phase_out_threshold_joint": 400_000,
            "phase_out_threshold_other": 200_000,
        },
        {
            "name": "uncapped",
            "cap_joint": float("inf"),
            "cap_other": float("inf"),
            "phase_out": False,
            "phase_out_rate": 0,
            "phase_out_threshold_joint": 0,
            "phase_out_threshold_other": 0,
        },
    ]

    # AMT configurations with explicit joint/non-joint amounts for 2026
    amt_configs = [
        {
            "name": "repealed",
            "exemption_joint": float("inf"),
            "exemption_other": float("inf"),
            "phase_out_joint": 0,
            "phase_out_other": 0
        },
        {
            "name": "pre_tcja_ex_tcja_po",
            "exemption_joint": 140_565,
            "exemption_other": 90_394,
            "phase_out_joint": 1_285_409,
            "phase_out_other": 642_705
        },
        {
            "name": "pre_tcja_ex_tcja_po",
            "exemption_joint": 140_565,
            "exemption_other": 90_394,
            "phase_out_joint": 209_000,
            "phase_out_other": 156_700
        },
        {
            "name": "tcja_ex_pre_tcja_po",
            "exemption_joint": 109_700,
            "exemption_other": 70_500,
            "phase_out_joint": 1_285_409,
            "phase_out_other": 642_705
        },
        {
            "name": "tcja_both",
            "exemption_joint": 109_700,
            "exemption_other": 70_500,
            "phase_out_joint": 209_000,
            "phase_out_other": 156_700
        },
    ]

    behavioral = [True, False]

    return list(product(salt_configs, amt_configs, behavioral))

# %%
def get_behavioral_reform():
    """Returns the behavioral response reform parameters"""
    return {
        "gov.simulation.labor_supply_responses.elasticities.income": {
            "2024-01-01.2100-12-31": -0.05
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.1": {
            "2024-01-01.2100-12-31": 0.31
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.10": {
            "2024-01-01.2100-12-31": 0.22
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.2": {
            "2024-01-01.2100-12-31": 0.28
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.3": {
            "2024-01-01.2100-12-31": 0.27
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.4": {
            "2024-01-01.2100-12-31": 0.27
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.5": {
            "2024-01-01.2100-12-31": 0.25
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.6": {
            "2024-01-01.2100-12-31": 0.25
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.7": {
            "2024-01-01.2100-12-31": 0.22
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.8": {
            "2024-01-01.2100-12-31": 0.22
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.9": {
            "2024-01-01.2100-12-31": 0.22
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.secondary": {
            "2024-01-01.2100-12-31": 0.27
        }
    }

# %%
def create_reform_dict(salt_config, amt_config, behavioral):
    """Create reform dictionary with optional behavioral responses"""
    reform_dict = {}
    
    # SALT caps
    reform_dict.update({
        "gov.irs.deductions.itemized.salt_and_real_estate.cap.JOINT": {
            "2026-01-01.2100-12-31": salt_config["cap_joint"]
        },
        "gov.irs.deductions.itemized.salt_and_real_estate.cap.SURVIVING_SPOUSE": {
            "2026-01-01.2100-12-31": salt_config["cap_joint"]
        },
        "gov.irs.deductions.itemized.salt_and_real_estate.cap.SEPARATE": {
            "2026-01-01.2100-12-31": salt_config["cap_joint"] / 2
        },
        "gov.irs.deductions.itemized.salt_and_real_estate.cap.SINGLE": {
            "2026-01-01.2100-12-31": salt_config["cap_other"]
        },
        "gov.irs.deductions.itemized.salt_and_real_estate.cap.HEAD_OF_HOUSEHOLD": {
            "2026-01-01.2100-12-31": salt_config["cap_other"]
        },
        # Add phase-out parameters
        "gov.contrib.salt_phase_out.in_effect": {
            "2026-01-01.2100-12-31": salt_config["phase_out"]
        },
        "gov.contrib.salt_phase_out.rate.other[1].rate": {
            "2026-01-01.2100-12-31": salt_config["phase_out_rate"] if salt_config["phase_out"] else 0
        },
        "gov.contrib.salt_phase_out.rate.joint[1].threshold": {
            "2026-01-01.2100-12-31": salt_config["phase_out_threshold_joint"] if salt_config["phase_out"] else 0
        },
        "gov.contrib.salt_phase_out.rate.other[1].threshold": {
            "2026-01-01.2100-12-31": salt_config["phase_out_threshold_other"] if salt_config["phase_out"] else 0
        }
    })

    # AMT parameters - only if not repealed
    reform_dict.update({
        "gov.irs.income.amt.exemption.amount.JOINT": {
            "2026-01-01.2026-12-31": amt_config["exemption_joint"]
        },
        "gov.irs.income.amt.exemption.amount.SURVIVING_SPOUSE": {
            "2026-01-01.2026-12-31": amt_config["exemption_joint"]
        },
        "gov.irs.income.amt.exemption.amount.SEPARATE": {
            "2026-01-01.2026-12-31": amt_config["exemption_joint"] / 2
        },
        "gov.irs.income.amt.exemption.amount.SINGLE": {
            "2026-01-01.2026-12-31": amt_config["exemption_other"]
        },
        "gov.irs.income.amt.exemption.amount.HEAD_OF_HOUSEHOLD": {
            "2026-01-01.2026-12-31": amt_config["exemption_other"]
        },
        # Phase-out thresholds
        "gov.irs.income.amt.exemption.phase_out.start.JOINT": {
            "2026-01-01.2026-12-31": amt_config["phase_out_joint"]
        },
        "gov.irs.income.amt.exemption.phase_out.start.SURVIVING_SPOUSE": {
            "2026-01-01.2026-12-31": amt_config["phase_out_joint"]
        },
        "gov.irs.income.amt.exemption.phase_out.start.SEPARATE": {
            "2026-01-01.2026-12-31": amt_config["phase_out_joint"] / 2
        },
        "gov.irs.income.amt.exemption.phase_out.start.SINGLE": {
            "2026-01-01.2026-12-31": amt_config["phase_out_other"]
        },
        "gov.irs.income.amt.exemption.phase_out.start.HEAD_OF_HOUSEHOLD": {
            "2026-01-01.2026-12-31": amt_config["phase_out_other"]
        }
    })

    # Add behavioral responses if enabled
    if behavioral:
        reform_dict.update(get_behavioral_reform())
    
    return reform_dict

# %%
def get_tcja_extension_reform():
    """Returns the reform dictionary for TCJA extension"""
    return {
        "gov.irs.credits.ctc.amount.base[0].amount": {
            "2026-01-01.2100-12-31": 2000
        },
        "gov.irs.credits.ctc.phase_out.threshold.HEAD_OF_HOUSEHOLD": {
            "2026-01-01.
SURVIVING_SPOUSE": {
            "2026-01-01.2026-12-31": 1000000,
            "2027-01-01.2027-12-31": 1000000,
            "2028-01-01.2028-12-31": 1000000,
            "2029-01-01.2029-12-31": 1000000,
            "2030-01-01.2030-12-31": 1000000,
            "2031-01-01.2031-12-31": 1000000,
            "2032-01-01.2032-12-31": 1000000,
            "2033-01-01.2033-12-31": 1000000,
            "2034-01-01.2034-12-31": 1000000
        },
        "gov.irs.deductions.itemized.limitation.itemized_deduction_rate": {
            "2026-01-01.2026-12-31": 1,
            "2027-01-01.2027-12-31": 1,
            "2028-01-01.2028-12-31": 1,
            "2029-01-01.2029-12-31": 1,
            "2030-01-01.2030-12-31": 1,
            "2031-01-01.2031-12-31": 1,
            "2032-01-01.2032-12-31": 1,
            "2033-01-01.2033-12-31": 1,
            "2034-01-01.2034-12-31": 1
        },
        "gov.irs.deductions.itemized.salt_and_real_estate.cap.HEAD_OF_HOUSEHOLD": {
            "2026-01-01.2100-12-31": 10000
        },
        "gov.irs.deductions.itemized.salt_and_real_estate.cap.JOINT": {
            "2026-01-01.2100-12-31": 10000
        },
        "gov.irs.deductions.itemized.salt_and_real_estate.cap.SEPARATE": {
            "2026-01-01.2100-12-31": 5000
        },
        "gov.irs.deductions.itemized.salt_and_real_estate.cap.SINGLE": {
            "2026-01-01.2100-12-31": 10000
        },
        "gov.irs.deductions.itemized.salt_and_real_estate.cap.SURVIVING_SPOUSE": {
            "2026-01-01.2100-12-31": 10000
        },
        "gov.irs.deductions.qbi.max.business_property.rate": {
            "2026-01-01.2100-12-31": 0.025
        },
        "gov.irs.deductions.qbi.max.rate": {
            "2026-01-01.2100-12-31": 0.2
        },
        "gov.irs.deductions.qbi.max.w2_wages.alt_rate": {
            "2026-01-01.2100-12-31": 0.25
        },
        "gov.irs.deductions.qbi.max.w2_wages.rate": {
            "2026-01-01.2100-12-31": 0.5
        },
        "gov.irs.deductions.qbi.phase_out.length.HEAD_OF_HOUSEHOLD": {
            "2026-01-01.2100-12-31": 50000
        },
        "gov.irs.deductions.qbi.phase_out.length.JOINT": {
            "2026-01-01.2100-12-31": 100000
        },
        "gov.irs.deductions.qbi.phase_out.length.SEPARATE": {
            "2026-01-01.2100-12-31": 50000
        },
        "gov.irs.deductions.qbi.phase_out.length.SINGLE": {
            "2026-01-01.2100-12-31": 50000
        },
        "gov.irs.deductions.qbi.phase_out.length.SURVIVING_SPOUSE": {
            "2026-01-01.2100-12-31": 100000
        },
        "gov.irs.deductions.qbi.phase_out.start.HEAD_OF_HOUSEHOLD": {
            "2024-01-01.2024-12-31": 198225,
            "2025-01-01.2025-12-31": 200275,
            "2026-01-01.2026-12-31": 204900,
            "2027-01-01.2027-12-31": 209050,
            "2028-01-01.2028-12-31": 213075,
            "2029-01-01.2029-12-31": 217125,
            "2030-01-01.2030-12-31": 221375,
            "2031-01-01.2031-12-31": 225775,
            "2032-01-01.2032-12-31": 230275,
            "2033-01-01.2033-12-31": 234875,
            "2034-01-01.2034-12-31": 239600,
            "2035-01-01.2035-12-31": 244450
        },
        "gov.irs.deductions.qbi.phase_out.start.JOINT": {
            "2024-01-01.2024-12-31": 396450,
            "2025-01-01.2025-12-31": 400575,
            "2026-01-01.2026-12-31": 409800,
            "2027-01-01.2027-12-31": 418100,
            "2028-01-01.2028-12-31": 426175,
            "2031-01-01.2031-12-31": 845250,
            "2032-01-01.2032-12-31": 862100,
            "2033-01-01.2033-12-31": 879350,
            "2034-01-01.2034-12-31": 897050,
            "2035-01-01.2035-12-31": 915200
        },
        "gov.irs.income.exemption.amount": {
            "2026-01-01.2100-12-31": 0
        }
    }

# %%
def calculate_gini(income):
    sorted_income = np.sort(income)
    n = len(income)
    index = np.arange(1, n + 1)
    return ((2 * index - n - 1) * sorted_income).sum() / (n * sorted_income.sum())

# %%
def calculate_metrics(simulation, year):
    """Calculate raw metrics for a given simulation"""
    # Income
    income = simulation.calculate("household_net_income", period=year)
    
    # Poverty
    poverty = simulation.calculate("in_poverty", map_to="person", period=year)
    poverty_rate = poverty.mean()
    
    # Filter out negative decile values
    decile = simulation.calculate("household_income_decile", period=year)
    income_filtered = income[decile >= 1]
    
    # Calculate average income by decile
    avg_income_by_decile = (
        income_filtered.groupby(decile[decile >= 1]).sum()
        / income_filtered.groupby(decile[decile >= 1]).count()
    )
    
    # Convert decile values to dictionary format
    decile_values = {
        f"income_p{i}0_{i+1}0": avg_income_by_decile[i + 1]
        for i in range(10)
    }
    
    return {
        "total_income": income.sum(),
        "poverty_rate": poverty_rate,
        "inequality": calculate_gini(income_filtered),
        **decile_values
    }

# %%
# Generate and sort combinations
combinations = generate_policy_combinations()
# Sort combinations so that behavioral=False comes first, then behavioral=True
combinations.sort(key=lambda x: (x[2], x[0]["name"], x[1]["name"]))

# %%
EXPECTED_COLUMNS = [
    "scenario",
    "total_income",
    "poverty_rate",
    "inequality",
] + [f"income_p{i}0_{i+1}0" for i in range(10)]

# Create or load existing results
results_file = "../data/raw_metrics.csv"
try:
    existing_results = pd.read_csv(results_file)
    # Ensure all expected columns exist
    for col in EXPECTED_COLUMNS:
        if col not in existing_results.columns:
            existing_results[col] = None
    # Reorder columns to match expected order
    existing_results = existing_results[EXPECTED_COLUMNS]
    completed_scenarios = set(existing_results["scenario"].tolist())
    print(f"Found {len(completed_scenarios)} completed scenarios")
except (FileNotFoundError, pd.errors.EmptyDataError, pd.errors.ParserError):
    existing_results = pd.DataFrame(columns=EXPECTED_COLUMNS)
    completed_scenarios = set()
    print("Starting fresh with no existing results")

# First, calculate baseline scenario if not already done
if "baseline" not in completed_scenarios:
    print("Calculating baseline scenario")
    baseline = Microsimulation(dataset='enhanced_cps_2024')
    baseline_metrics = calculate_metrics(baseline, "2026")
    baseline_row = pd.DataFrame([{
        "scenario": "baseline",
        **baseline_metrics
    }])[EXPECTED_COLUMNS]
    existing_results = pd.concat([existing_results, baseline_row], ignore_index=True)
    existing_results.to_csv(results_file, index=False)
    completed_scenarios.add("baseline")

# Then calculate TCJA extension baseline if not already done
if "tcja_extension_baseline" not in completed_scenarios:
    print("Calculating TCJA extension baseline")
    tcja_reform = Reform.from_dict(get_tcja_extension_reform(), country_id="us")
    tcja_baseline = Microsimulation(reform=tcja_reform, dataset='enhanced_cps_2024')
    tcja_metrics = calculate_metrics(tcja_baseline, "2026")
    tcja_row = pd.DataFrame([{
        "scenario": "tcja_extension_baseline",
        **tcja_metrics
    }])[EXPECTED_COLUMNS]
    existing_results = pd.concat([existing_results, tcja_row], ignore_index=True)
    existing_results.to_csv(results_file, index=False)
    completed_scenarios.add("tcja_extension_baseline")

# Generate combinations and split into non-behavioral and behavioral
combinations = generate_policy_combinations()
non_behavioral_combinations = [(s, a, b) for s, a, b in combinations if not b]
behavioral_combinations = [(s, a, b) for s, a, b in combinations if b]

print(f"Processing {len(non_behavioral_combinations)} non-behavioral combinations first")
print(f"Then will process {len(behavioral_combinations)} behavioral combinations")

# Process non-behavioral combinations first
for salt_config, amt_config, behavioral in non_behavioral_combinations:
    scenario_name = f"salt_{salt_config['name']}_amt_{amt_config['name']}_behavioral_responses{'_yes' if behavioral else '_no'}"
    
    if scenario_name in completed_scenarios:
        print(f"Skipping {scenario_name} - already calculated")
        continue
    
    print(f"Calculating {scenario_name}")
    
    try:
        reform_dict = create_reform_dict(salt_config, amt_config, behavioral)
        reform = Reform.from_dict(reform_dict, country_id="us")
        reformed = Microsimulation(reform=reform, dataset='enhanced_cps_2024')
        metrics = calculate_metrics(reformed, "2026")
        
        new_row = pd.DataFrame([{
            "scenario": scenario_name,
            **metrics
        }])[EXPECTED_COLUMNS]
        
        existing_results = pd.concat([existing_results, new_row], ignore_index=True)
        existing_results.to_csv(results_file, index=False)
        completed_scenarios.add(scenario_name)
        
        print(f"Completed and saved {scenario_name}")
        
    except Exception as e:
        print(f"Error calculating {scenario_name}: {str(e)}")
        with open("../data/error_log.txt", "a") as f:
            f.write(f"\nError on {scenario_name}: {str(e)}")
        continue

print("Completed all non-behavioral combinations")
print("Starting behavioral combinations")

# Then process behavioral combinations
for salt_config, amt_config, behavioral in behavioral_combinations:
    scenario_name = f"salt_{salt_config['name']}_amt_{amt_config['name']}_behavioral_responses{'_yes' if behavioral else '_no'}"
    
    if scenario_name in completed_scenarios:
        print(f"Skipping {scenario_name} - already calculated")
        continue
    
    print(f"Calculating {scenario_name}")
    
    try:
        reform_dict = create_reform_dict(salt_config, amt_config, behavioral)
        reform = Reform.from_dict(reform_dict, country_id="us")
        reformed = Microsimulation(reform=reform, dataset='enhanced_cps_2024')
        metrics = calculate_metrics(reformed, "2026")
        
        new_row = pd.DataFrame([{
            "scenario": scenario_name,
            **metrics
        }])[EXPECTED_COLUMNS]
        
        existing_results = pd.concat([existing_results, new_row], ignore_index=True)
        existing_results.to_csv(results_file, index=False)
        completed_scenarios.add(scenario_name)
        
        print(f"Completed and saved {scenario_name}")
        
    except Exception as e:
        print(f"Error calculating {scenario_name}: {str(e)}")
        with open("../data/error_log.txt", "a") as f:
            f.write(f"\nError on {scenario_name}: {str(e)}")
        continue

print(f"Completed {len(completed_scenarios)} out of {len(combinations) + 2} possible scenarios")
# Out:
# Found 2 completed scenarios
# Processing 30 non-behavioral combinations first
# Then will process 30 behavioral combinations
# Calculating salt_0_cap_amt_repealed_behavioral_responses_no
# Completed and saved salt_0_cap_amt_repealed_behavioral_responses_no
# Calculating salt_0_cap_amt_pre_tcja_ex_tcja_po_behavioral_responses_no
# Completed and saved salt_0_cap_amt_pre_tcja_ex_tcja_po_behavioral_responses_no
# Skipping salt_0_cap_amt_pre_tcja_ex_tcja_po_behavioral_responses_no - already calculated
# Calculating salt_0_cap_amt_tcja_ex_pre_tcja_po_behavioral_responses_no
# Completed and saved salt_0_cap_amt_tcja_ex_pre_tcja_po_behavioral_responses_no
# Calculating salt_0_cap_amt_tcja_both_behavioral_responses_no
# Completed and saved salt_0_cap_amt_tcja_both_behavioral_responses_no
# Calculating salt_tcja_base_amt_repealed_behavioral_responses_no
# Completed and saved salt_tcja_base_amt_repealed_behavioral_responses_no
# Calculating salt_tcja_base_amt_pre_tcja_ex_tcja_po_behavioral_responses_no
# Completed and saved salt_tcja_base_amt_pre_tcja_ex_tcja_po_behavioral_responses_no
# Skipping salt_tcja_base_amt_pre_tcja_ex_tcja_po_behavioral_responses_no - already calculated
# Calculating salt_tcja_base_amt_tcja_ex_pre_tcja_po_behavioral_responses_no
# Completed and saved salt_tcja_base_amt_tcja_ex_pre_tcja_po_behavioral_responses_no
# Calculating salt_tcja_base_amt_tcja_both_behavioral_responses_no
# Completed and saved salt_tcja_base_amt_tcja_both_behavioral_responses_no
# Calculating salt_tcja_base_with_married_bonus_amt_repealed_behavioral_responses_no
# Completed and saved salt_tcja_base_with_married_bonus_amt_repealed_behavioral_responses_no
# Calculating salt_tcja_base_with_married_bonus_amt_pre_tcja_ex_tcja_po_behavioral_responses_no
# Completed and saved salt_tcja_base_with_married_bonus_amt_pre_tcja_ex_tcja_po_behavioral_responses_no
# Skipping salt_tcja_base_with_married_bonus_amt_pre_tcja_ex_tcja_po_behavioral_responses_no - already calculated
# Calculating salt_tcja_base_with_married_bonus_amt_tcja_ex_pre_tcja_po_behavioral_responses_no
# Completed and saved salt_tcja_base_with_married_bonus_amt_tcja_ex_pre_tcja_po_behavioral_responses_no
# Calculating salt_tcja_base_with_married_bonus_amt_tcja_both_behavioral_responses_no
# Completed and saved salt_tcja_base_with_married_bonus_amt_tcja_both_behavioral_responses_no
# Calculating salt_tcja_base_with_phaseout_amt_repealed_behavioral_responses_no
# Completed and saved salt_tcja_base_with_phaseout_amt_repealed_behavioral_responses_no
# Calculating salt_tcja_base_with_phaseout_amt_pre_tcja_ex_tcja_po_behavioral_responses_no
# Completed and saved salt_tcja_base_with_phaseout_amt_pre_tcja_ex_tcja_po_behavioral_responses_no
# Skipping salt_tcja_base_with_phaseout_amt_pre_tcja_ex_tcja_po_behavioral_responses_no - already calculated
# Calculating salt_tcja_base_with_phaseout_amt_tcja_ex_pre_tcja_po_behavioral_responses_no
# Completed and saved salt_tcja_base_with_phaseout_amt_tcja_ex_pre_tcja_po_behavioral_responses_no
# Calculating salt_tcja_base_with_phaseout_amt_tcja_both_behavioral_responses_no
# Completed and saved salt_tcja_base_with_phaseout_amt_tcja_both_behavioral_responses_no
# Calculating salt_tcja_married_bonus_and_phase_out_amt_repealed_behavioral_responses_no
# Completed and saved salt_tcja_married_bonus_and_phase_out_amt_repealed_behavioral_responses_no
# Calculating salt_tcja_married_bonus_and_phase_out_amt_pre_tcja_ex_tcja_po_behavioral_responses_no
# Completed and saved salt_tcja_married_bonus_and_phase_out_amt_pre_tcja_ex_tcja_po_behavioral_responses_no
# Skipping salt_tcja_married_bonus_and_phase_out_amt_pre_tcja_ex_tcja_po_behavioral_responses_no - already calculated
# Calculating salt_tcja_married_bonus_and_phase_out_amt_tcja_ex_pre_tcja_po_behavioral_responses_no
# Completed and saved salt_tcja_married_bonus_and_phase_out_amt_tcja_ex_pre_tcja_po_behavioral_responses_no
# Calculating salt_tcja_married_bonus_and_phase_out_amt_tcja_both_behavioral_responses_no
# Completed and saved salt_tcja_married_bonus_and_phase_out_amt_tcja_both_behavioral_responses_no
# Calculating salt_uncapped_amt_repealed_behavioral_responses_no
# Completed and saved salt_uncapped_amt_repealed_behavioral_responses_no
# Calculating salt_uncapped_amt_pre_tcja_ex_tcja_po_behavioral_responses_no
# Completed and saved salt_uncapped_amt_pre_tcja_ex_tcja_po_behavioral_responses_no
# Skipping salt_uncapped_amt_pre_tcja_ex_tcja_po_behavioral_responses_no - already calculated
# Calculating salt_uncapped_amt_tcja_ex_pre_tcja_po_behavioral_responses_no
# Completed and saved salt_uncapped_amt_tcja_ex_pre_tcja_po_behavioral_responses_no
# Calculating salt_uncapped_amt_tcja_both_behavioral_responses_no
# Completed and saved salt_uncapped_amt_tcja_both_behavioral_responses_no
# Completed all non-behavioral combinations
# Starting behavioral combinations
# Calculating salt_0_cap_amt_repealed_behavioral_responses_yes
# Completed and saved salt_0_cap_amt_repealed_behavioral_responses_yes
# Calculating salt_0_cap_amt_pre_tcja_ex_tcja_po_behavioral_responses_yes
# Completed and saved salt_0_cap_amt_pre_tcja_ex_tcja_po_behavioral_responses_yes
# Skipping salt_0_cap_amt_pre_tcja_ex_tcja_po_behavioral_responses_yes - already calculated
# Calculating salt_0_cap_amt_tcja_ex_pre_tcja_po_behavioral_responses_yes
# Completed and saved salt_0_cap_amt_tcja_ex_pre_tcja_po_behavioral_responses_yes
# Calculating salt_0_cap_amt_tcja_both_behavioral_responses_yes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 110
#     108 reform = Reform.from_dict(reform_dict, country_id="us")
#     109 reformed = Microsimulation(reform=reform, dataset='enhanced_cps_2024')
# --> 110 metrics = calculate_metrics(reformed, "2026")
#     112 new_row = pd.DataFrame([{
#     113     "scenario": scenario_name,
#     114     **metrics
#     115 }])[EXPECTED_COLUMNS]
#     117 existing_results = pd.concat([existing_results, new_row], ignore_index=True)
#
# Cell In[7], line 4, in calculate_metrics(simulation, year)
#       2 """Calculate raw metrics for a given simulation"""
#       3 # Income
# ----> 4 income = simulation.calculate("household_net_income", period=year)
#       6 # Poverty
#       7 poverty = simulation.calculate("in_poverty", map_to="person", period=year)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:905, in Simulation._run_formula(self, variable, population, period)
#     903 for added_variable in adds_list:
#     904     if added_variable in self.tax_benefit_system.variables:
# --> 905         values = values + self.calculate(
#     906             added_variable, period, map_to=variable.entity.key
#     907         )
#     908     else:
#     909         try:
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:905, in Simulation._run_formula(self, variable, population, period)
#     903 for added_variable in adds_list:
#     904     if added_variable in self.tax_benefit_system.variables:
# --> 905         values = values + self.calculate(
#     906             added_variable, period, map_to=variable.entity.key
#     907         )
#     908     else:
#     909         try:
#
#     [... skipping similar frames: Simulation._calculate at line 688 (1 times), Microsimulation.calculate at line 54 (1 times), Simulation.calculate at line 463 (1 times)]
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:905, in Simulation._run_formula(self, variable, population, period)
#     903 for added_variable in adds_list:
#     904     if added_variable in self.tax_benefit_system.variables:
# --> 905         values = values + self.calculate(
#     906             added_variable, period, map_to=variable.entity.key
#     907         )
#     908     else:
#     909         try:
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:970, in Simulation._run_formula(self, variable, population, period)
#     968     array = formula(population, period)
#     969 else:
# --> 970     array = formula(population, period, parameters_at)
#     972 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/simulation/labor_supply_response/labor_supply_response.py:282, in employment_income_behavioral_response.formula(person, period, parameters)
#     281 def formula(person, period, parameters):
# --> 282     lsr = person("labor_supply_behavioral_response", period)
#     283     employment_income = person("employment_income_before_lsr", period)
#     284     self_employment_income = person(
#     285         "self_employment_income_before_lsr", period
#     286     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:970, in Simulation._run_formula(self, variable, population, period)
#     968     array = formula(population, period)
#     969 else:
# --> 970     array = formula(population, period, parameters_at)
#     972 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/simulation/labor_supply_response/labor_supply_response.py:254, in labor_supply_behavioral_response.formula(person, period, parameters)
#     243     branch.set_input(
#     244         "employment_income_before_lsr",
#     245         period,
#     246         person("employment_income_before_lsr", period),
#     247     )
#     248     branch.set_input(
#     249         "self_employment_income_before_lsr",
#     250         period,
#     251         person("self_employment_income_before_lsr", period),
#     252     )
# --> 254 response = add(
#     255     person,
#     256     period,
#     257     [
#     258         "income_elasticity_lsr",
#     259         "substitution_elasticity_lsr",
#     260     ],
#     261 )
#     262 simulation = person.simulation
#     263 del simulation.branches["baseline"].branches[
#     264     "baseline_lsr_measurement"
#     265 ]
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:970, in Simulation._run_formula(self, variable, population, period)
#     968     array = formula(population, period)
#     969 else:
# --> 970     array = formula(population, period, parameters_at)
#     972 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/simulation/labor_supply_response/labor_supply_response.py:85, in income_elasticity_lsr.formula(person, period, parameters)
#      81 self_employment_income = person(
#      82     "self_employment_income_before_lsr", period
#      83 )
#      84 earnings = employment_income + self_employment_income
# ---> 85 income_change = person("relative_income_change", period)
#      86 return earnings * income_change * person("income_elasticity", period)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:970, in Simulation._run_formula(self, variable, population, period)
#     968     array = formula(population, period)
#     969 else:
# --> 970     array = formula(population, period, parameters_at)
#     972 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/simulation/labor_supply_response/labor_supply_response.py:23, in relative_income_change.formula(person, period, parameters)
#      19 baseline_net_income = baseline_person.household(
#      20     "household_net_income", period
#      21 )
#      22 measurement_person = measurement_branch.populations["person"]
# ---> 23 net_income = measurement_person.household(
#      24     "household_net_income", period
#      25 )
#      26 income_change_bound = parameters(
#      27     period
#      28 ).gov.simulation.labor_supply_responses.bounds.income_change
#      29 # _c suffix for "clipped"
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/projectors/projector.py:33, in Projector.__call__(self, *args, **kwargs)
#      32 def __call__(self, *args, **kwargs):
# ---> 33     result = self.reference_entity(*args, **kwargs)
#      34     return self.transform_and_bubble_up(result)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:905, in Simulation._run_formula(self, variable, population, period)
#     903 for added_variable in adds_list:
#     904     if added_variable in self.tax_benefit_system.variables:
# --> 905         values = values + self.calculate(
#     906             added_variable, period, map_to=variable.entity.key
#     907         )
#     908     else:
#     909         try:
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:905, in Simulation._run_formula(self, variable, population, period)
#     903 for added_variable in adds_list:
#     904     if added_variable in self.tax_benefit_system.variables:
# --> 905         values = values + self.calculate(
#     906             added_variable, period, map_to=variable.entity.key
#     907         )
#     908     else:
#     909         try:
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:654, in Simulation._calculate(self, variable_name, period)
#     652         values = self._calculate(variable_name, contained_months[-1])
#     653     else:
# --> 654         values = self.calculate_add(variable_name, period)
#     655     alternate_period_handling = True
#     656 elif variable.definition_period == YEAR and period.unit == MONTH:
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:67, in Microsimulation.calculate_add(self, variable_name, period, map_to, use_weights)
#      60 def calculate_add(
#      61     self,
#      62     variable_name: str,
#    (...)
#      65     use_weights: bool = True,
#      66 ) -> MicroSeries:
# ---> 67     values = super().calculate_add(variable_name, period, map_to)
#      68     if not use_weights:
#      69         return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:811, in Simulation.calculate_add(self, variable_name, period, decode_enums)
#     800 if variable.definition_period not in [
#     801     periods.DAY,
#     802     periods.MONTH,
#     803     periods.YEAR,
#     804 ]:
#     805     raise ValueError(
#     806         "Unable to sum constant variable '{}' over period {}: only variables defined daily, monthly, or yearly can be summed over time.".format(
#     807             variable.name, period
#     808         )
#     809     )
# --> 811 result = sum(
#     812     self.calculate(variable_name, sub_period)
#     813     for sub_period in period.get_subperiods(variable.definition_period)
#     814 )
#     815 holder = self.get_holder(variable.name)
#     816 holder.put_in_cache(result, period, self.branch_name)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:812, in <genexpr>(.0)
#     800 if variable.definition_period not in [
#     801     periods.DAY,
#     802     periods.MONTH,
#     803     periods.YEAR,
#     804 ]:
#     805     raise ValueError(
#     806         "Unable to sum constant variable '{}' over period {}: only variables defined daily, monthly, or yearly can be summed over time.".format(
#     807             variable.name, period
#     808         )
#     809     )
#     811 result = sum(
# --> 812     self.calculate(variable_name, sub_period)
#     813     for sub_period in period.get_subperiods(variable.definition_period)
#     814 )
#     815 holder = self.get_holder(variable.name)
#     816 holder.put_in_cache(result, period, self.branch_name)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:970, in Simulation._run_formula(self, variable, population, period)
#     968     array = formula(population, period)
#     969 else:
# --> 970     array = formula(population, period, parameters_at)
#     972 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/usda/snap/snap.py:25, in snap.formula(spm_unit, period, parameters)
#      23     return spm_unit("snap_reported", period) / MONTHS_IN_YEAR
#      24 else:
# ---> 25     value = add(
#      26         spm_unit,
#      27         period,
#      28         [
#      29             "snap_normal_allotment",
#      30             "snap_emergency_allotment",
#      31             "dc_snap_temporary_local_benefit",
#      32         ],
#      33     )
#      34     if is_in_microsim:
#      35         return value * takes_up
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:970, in Simulation._run_formula(self, variable, population, period)
#     968     array = formula(population, period)
#     969 else:
# --> 970     array = formula(population, period, parameters_at)
#     972 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/usda/snap/snap_normal_allotment.py:16, in snap_normal_allotment.formula(spm_unit, period, parameters)
#      13 def formula(spm_unit, period, parameters):
#      14     # Federal SNAP rules are defined in U.S.C Title 7, Chapter 51, which
#      15     # also defines state powers to modify the rules.
# ---> 16     eligible = spm_unit("is_snap_eligible", period)
#      17     expected_contribution = spm_unit("snap_expected_contribution", period)
#      18     max_allotment = spm_unit("snap_max_allotment", period)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:970, in Simulation._run_formula(self, variable, population, period)
#     968     array = formula(population, period)
#     969 else:
# --> 970     array = formula(population, period, parameters_at)
#     972 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/usda/snap/eligibility/is_snap_eligible.py:16, in is_snap_eligible.formula(spm_unit, period, parameters)
#      15 def formula(spm_unit, period, parameters):
# ---> 16     net = spm_unit("meets_snap_net_income_test", period)
#      17     gross = spm_unit("meets_snap_gross_income_test", period)
#      18     asset = spm_unit("meets_snap_asset_test", period)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:970, in Simulation._run_formula(self, variable, population, period)
#     968     array = formula(population, period)
#     969 else:
# --> 970     array = formula(population, period, parameters_at)
#     972 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/usda/snap/eligibility/meets_snap_net_income_test.py:19, in meets_snap_net_income_test.formula(spm_unit, period, parameters)
#      15 def formula(spm_unit, period, parameters):
#      16     net_income_limit_fpg = parameters(
#      17         period
#      18     ).gov.usda.snap.income.limit.net
# ---> 19     net_income_fpg = spm_unit("snap_net_income_fpg_ratio", period)
#      20     return net_income_fpg <= net_income_limit_fpg
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:968, in Simulation._run_formula(self, variable, population, period)
#     965 parameters_at = self.tax_benefit_system.parameters
#     967 if formula.__code__.co_argcount == 2:
# --> 968     array = formula(population, period)
#     969 else:
#     970     array = formula(population, period, parameters_at)
#
# File ~/policyengine-us/policyengine_us/variables/gov/usda/snap/income/snap_net_income_fpg_ratio.py:15, in snap_net_income_fpg_ratio.formula(spm_unit, period)
#      14 def formula(spm_unit, period):
# ---> 15     income = spm_unit("snap_net_income", period)
#      16     fpg = spm_unit("snap_fpg", period)
#      17     return income / fpg
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:968, in Simulation._run_formula(self, variable, population, period)
#     965 parameters_at = self.tax_benefit_system.parameters
#     967 if formula.__code__.co_argcount == 2:
# --> 968     array = formula(population, period)
#     969 else:
#     970     array = formula(population, period, parameters_at)
#
# File ~/policyengine-us/policyengine_us/variables/gov/usda/snap/income/snap_net_income.py:15, in snap_net_income.formula(spm_unit, period)
#      13 def formula(spm_unit, period):
#      14     gross_income = spm_unit("snap_gross_income", period)
# ...
#      14     resources_eligible = spm_unit("ca_tanf_resources_eligible", period)
#      15     vehicle_value_eligible = spm_unit(
#      16         "ca_tanf_vehicle_value_eligible", period
#      17     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:970, in Simulation._run_formula(self, variable, population, period)
#     968     array = formula(population, period)
#     969 else:
# --> 970     array = formula(population, period, parameters_at)
#     972 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/states/ca/cdss/tanf/cash/eligibility/ca_tanf_financial_eligible.py:13, in ca_tanf_financial_eligible.formula(spm_unit, period, parameters)
#      11 def formula(spm_unit, period, parameters):
#      12     tanf_enrolled = spm_unit("is_tanf_enrolled", period)
# ---> 13     applicant_test = spm_unit("ca_tanf_applicant_financial_test", period)
#      14     recipient_test = spm_unit("ca_tanf_recipient_financial_test", period)
#      16     return where(
#      17         tanf_enrolled, recipient_test, applicant_test & recipient_test
#      18     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:970, in Simulation._run_formula(self, variable, population, period)
#     968     array = formula(population, period)
#     969 else:
# --> 970     array = formula(population, period, parameters_at)
#     972 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/states/ca/cdss/tanf/cash/eligibility/ca_tanf_applicant_financial_test.py:16, in ca_tanf_applicant_financial_test.formula(spm_unit, period, parameters)
#      12 def formula(spm_unit, period, parameters):
#      13     countable_income_applicant = spm_unit(
#      14         "ca_tanf_countable_income_applicant", period
#      15     )
# ---> 16     income_limit = spm_unit("ca_tanf_income_limit", period)
#      18     return countable_income_applicant <= income_limit
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:970, in Simulation._run_formula(self, variable, population, period)
#     968     array = formula(population, period)
#     969 else:
# --> 970     array = formula(population, period, parameters_at)
#     972 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/states/ca/cdss/tanf/cash/eligibility/ca_tanf_income_limit.py:20, in ca_tanf_income_limit.formula(spm_unit, period, parameters)
#      18 au_size = min_(unit_size, p.max_au_size)
#      19 additional_people = unit_size - au_size
# ---> 20 region1 = spm_unit.household("ca_tanf_region1", period)
#      22 main_limit = where(
#      23     region1, p.region1.main[au_size], p.region2.main[au_size]
#      24 )
#      25 increase_per_additional_person = where(
#      26     region1, p.region1.additional, p.region2.additional
#      27 )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/projectors/projector.py:33, in Projector.__call__(self, *args, **kwargs)
#      32 def __call__(self, *args, **kwargs):
# ---> 33     result = self.reference_entity(*args, **kwargs)
#      34     return self.transform_and_bubble_up(result)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:970, in Simulation._run_formula(self, variable, population, period)
#     968     array = formula(population, period)
#     969 else:
# --> 970     array = formula(population, period, parameters_at)
#     972 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/states/ca/cdss/tanf/cash/eligibility/ca_tanf_region1.py:13, in ca_tanf_region1.formula(household, period, parameters)
#      12 def formula(household, period, parameters):
# ---> 13     county = household("county_str", period)
#      14     region1_counties = parameters(
#      15         period
#      16     ).gov.states.ca.cdss.tanf.cash.region1_counties
#      17     return np.isin(county, region1_counties)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:463, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     460 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     462 try:
# --> 463     result = self._calculate(variable_name, period)
#     464     if isinstance(result, EnumArray) and decode_enums:
#     465         result = result.decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:688, in Simulation._calculate(self, variable_name, period)
#     686 try:
#     687     self._check_for_cycle(variable.name, period)
# --> 688     array = self._run_formula(variable, population, period)
#     690     # If no result, use the default value and cache it
#     691     if array is None:
#     692         # Check if the variable has a previously defined value
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:970, in Simulation._run_formula(self, variable, population, period)
#     968     array = formula(population, period)
#     969 else:
# --> 970     array = formula(population, period, parameters_at)
#     972 return array
#
# File ~/policyengine-us/policyengine_us/variables/household/demographic/geographic/county/county_str.py:12, in county_str.formula(household, period, parameters)
#      11 def formula(household, period, parameters):
# ---> 12     return household("county", period).decode_to_str()
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/enums/enum_array.py:97, in EnumArray.decode_to_str(self)
#      85 def decode_to_str(self) -> numpy.str_:
#      86     """
#      87     Return the array of string identifiers corresponding to self.
#      88
#    (...)
#      95     'free_lodger'  # String identifier
#      96     """
# ---> 97     return numpy.select(
#      98         [self == item.index for item in self.possible_values],
#      99         [item.name for item in self.possible_values],
#     100     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/numpy/lib/function_base.py:864, in select(condlist, choicelist, default)
#     862 condlist = condlist[::-1]
#     863 for choice, cond in zip(choicelist, condlist):
# --> 864     np.copyto(result, choice, where=cond)
#     866 return result
#
# KeyboardInterrupt:

# %%
print(f"Completed {len(completed_scenarios)} out of {len(combinations) + 2} possible scenarios")

# %%
def add_impacts_to_single_year():
    """
    Calculate impacts by comparing each scenario to its respective baseline and 
    add results to single_year_impacts.csv
    """
    # Read the raw metrics
    raw_metrics = pd.read_csv("../data/raw_metrics.csv")
    
    # Get baseline values
    baseline = raw_metrics[raw_metrics["scenario"] == "baseline"].iloc[0]
    tcja_baseline = raw_metrics[raw_metrics["scenario"] == "tcja_extension_baseline"].iloc[0]
    
    # Initialize results DataFrame
    impacts = []
    
    # Process each non-baseline scenario
    for _, row in raw_metrics[~raw_metrics["scenario"].isin(["baseline", "tcja_extension_baseline"])].iterrows():
        scenario = row["scenario"]
        
        # Determine which baseline to use (TCJA extension or regular)
        comparison_baseline = tcja_baseline if "tcja" in scenario else baseline
        
        # Calculate differences
        impact = {
            "scenario": scenario,
            "total_income_impact": row["total_income"] - comparison_baseline["total_income"],
            "poverty_rate_impact": row["poverty_rate"] - comparison_baseline["poverty_rate"],
            "inequality_impact": row["inequality"] - comparison_baseline["inequality"]
        }
        
        # Add decile impacts
        for i in range(10):
            col = f"income_p{i}0_{i+1}0"
            impact[f"{col}_impact"] = row[col] - comparison_baseline[col]
        
        impacts.append(impact)
    
    # Convert to DataFrame
    impacts_df = pd.DataFrame(impacts)
    
    # Save to CSV
    impacts_df.to_csv("../data/single_year_impacts.csv", index=False)
    print(f"Saved impacts for {len(impacts)} scenarios")
    
    return impacts_df

# Execute the function
impacts = add_impacts_to_single_year()
