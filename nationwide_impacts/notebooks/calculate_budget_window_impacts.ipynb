# %%
import os
import pandas as pd
import numpy as np
from policyengine_us import Microsimulation
from policyengine_core.reforms import Reform
from itertools import product

# %%
# Add itemization branch
def get_itemization_branch():
    return {
        "gov.simulation.branch_to_determine_itemization": {
            "2026-01-01.2100-12-31": True
        }
    }

# %%
def generate_policy_combinations():
    # SALT configurations with explicit joint/non-joint amounts and phase-out parameters
    salt_configs = [
        {
            "name": "0_cap",
            "cap_joint": 0,
            "cap_other": 0,
            "phase_out": False,
            "phase_out_rate": 0,
            "phase_out_threshold_joint": 0,
            "phase_out_threshold_other": 0,
        },
        {
            "name": "tcja_base",
            "cap_joint": 10_000,
            "cap_other": 10_000,
            "phase_out": False,
            "phase_out_rate": 0,
            "phase_out_threshold_joint": 0,
            "phase_out_threshold_other": 0,
        },
        {
            "name": "tcja_base_with_married_bonus",
            "cap_joint": 20_000,
            "cap_other": 10_000,
            "phase_out": False,
            "phase_out_rate": 0,
            "phase_out_threshold_joint": 0,
            "phase_out_threshold_other": 0,
        },
        {
            "name": "tcja_base_with_phaseout",
            "cap_joint": 10_000,
            "cap_other": 10_000,
            "phase_out": True,
            "phase_out_rate": 0.1,  # 10%
            "phase_out_threshold_joint": 400_000,
            "phase_out_threshold_other": 200_000,
        },
        {
            "name": "15_30_k_with_phaseout",
            "cap_joint": 30_000,
            "cap_other": 15_000,
            "phase_out": True,
            "phase_out_rate": 0.1,  # 10%
            "phase_out_threshold_joint": 400_000,
            "phase_out_threshold_other": 200_000,
        },
        {
            "name": "15_30_k_without_phaseout",
            "cap_joint": 30_000,
            "cap_other": 15_000,
            "phase_out": False,
            "phase_out_rate": 0,
            "phase_out_threshold_joint": 0,
            "phase_out_threshold_other": 0,
        },
        {
            "name": "15_k_without_phaseout",
            "cap_joint": 15_000,
            "cap_other": 15_000,
            "phase_out": False,
            "phase_out_rate": 0,
            "phase_out_threshold_joint": 0,
            "phase_out_threshold_other": 0,
        },
        {
            "name": "15_k_with_phaseout",
            "cap_joint": 15_000,
            "cap_other": 15_000,
            "phase_out": True,
            "phase_out_rate": 0.1,
            "phase_out_threshold_joint": 400_000,
            "phase_out_threshold_other": 200_000,
        },
        {
            "name": "tcja_married_bonus_and_phase_out",
            "cap_joint": 20_000,
            "cap_other": 10_000,
            "phase_out": True,
            "phase_out_rate": 0.1,  # 10%
            "phase_out_threshold_joint": 400_000,
            "phase_out_threshold_other": 200_000,
        },
        {
            "name": "uncapped",
            "cap_joint": float("inf"),
            "cap_other": float("inf"),
            "phase_out": False,
            "phase_out_rate": 0,
            "phase_out_threshold_joint": 0,
            "phase_out_threshold_other": 0,
        },
        {
            "name": "uncapped_with_phaseout",
            "cap_joint": float("inf"),
            "cap_other": float("inf"),
            "phase_out": True,
            "phase_out_rate": 0.1,
            "phase_out_threshold_joint": 400_000,
            "phase_out_threshold_other": 200_000,
        },
        {
            "name": "100_200k_with_phaseout",
            "cap_joint": 200_000,
            "cap_other": 100_000,
            "phase_out": True,
            "phase_out_rate": 0.1,
            "phase_out_threshold_joint": 400_000,
            "phase_out_threshold_other": 200_000,
        },
        {
            "name": "100_200k_without_phaseout",
            "cap_joint": 200_000,
            "cap_other": 100_000,
            "phase_out": False,
            "phase_out_rate": 0,
            "phase_out_threshold_joint": 0,
            "phase_out_threshold_other": 0,
        },
        {
            "name": "100k_with_phaseout",
            "cap_joint": 100_000,
            "cap_other": 100_000,
            "phase_out": True,
            "phase_out_rate": 0.1,
            "phase_out_threshold_joint": 400_000,
            "phase_out_threshold_other": 200_000,
        },
        {
            "name": "100k_without_phaseout",
            "cap_joint": 100_000,
            "cap_other": 100_000,
            "phase_out": False,
            "phase_out_rate": 0,
            "phase_out_threshold_joint": 0,
            "phase_out_threshold_other": 0,
        },
    ]

    # AMT configurations with explicit joint/non-joint amounts for 2026
    amt_configs = [
        {
            "name": "repealed",
            "exemption_joint": {year: float("inf") for year in range(2026, 2036)},
            "exemption_other": {year: float("inf") for year in range(2026, 2036)},
            "phase_out_joint": {year: 0 for year in range(2026, 2036)},
            "phase_out_other": {year: 0 for year in range(2026, 2036)},
        },
        {
            "name": "pre_tcja_ex_pre_tcja_po",
            "exemption_joint": {
                2026: 139_850,
                2027: 142_675,
                2028: 145_425,
                2029: 148_200,
                2030: 151_100,
                2031: 154_100,
                2032: 157_150,
                2033: 160_300,
                2034: 163_525,
                2035: 166_850,
            },
            "exemption_other": {
                2026: 89_925,
                2027: 91_750,
                2028: 93_525,
                2029: 95_300,
                2030: 97_150,
                2031: 99_075,
                2032: 101_050,
                2033: 103_075,
                2034: 105_150,
                2035: 107_275,
            },
            "phase_out_joint": {
                2026: 1_278_575,
                2027: 1_304_475,
                2028: 1_329_675,
                2029: 1_354_850,
                2030: 1_381_475,
                2031: 1_408_825,
                2032: 1_436_875,
                2033: 1_465_650,
                2034: 1_495_150,
                2035: 1_525_375,
            },
            "phase_out_other": {
                2026: 639_300,
                2027: 652_250,
                2028: 664_825,
                2029: 677_425,
                2030: 690_725,
                2031: 704_400,
                2032: 718_425,
                2033: 732_825,
                2034: 747_575,
                2035: 762_675,
            },
        },
        {
            "name": "pre_tcja_ex_tcja_po",
            "exemption_joint": {
                2026: 139_850,
                2027: 142_675,
                2028: 145_425,
                2029: 148_200,
                2030: 151_100,
                2031: 154_100,
                2032: 157_150,
                2033: 160_300,
                2034: 163_525,
                2035: 166_850,
            },
            "exemption_other": {
                2026: 89_925,
                2027: 91_750,
                2028: 93_525,
                2029: 95_300,
                2030: 97_150,
                2031: 99_075,
                2032: 101_050,
                2033: 103_075,
                2034: 105_150,
                2035: 107_275,
            },
            "phase_out_joint": {
                2026: 209_000,
                2027: 213_200,
                2028: 217_400,
                2029: 221_600,
                2030: 226_000,
                2031: 230_400,
                2032: 234_800,
                2033: 239_200,
                2034: 243_600,
                2035: 248_000,
            },
            "phase_out_other": {
                2026: 156_900,
                2027: 160_200,
                2028: 163_400,
                2029: 166_700,
                2030: 170_000,
                2031: 173_300,
                2032: 176_800,
                2033: 180_300,
                2034: 183_800,
                2035: 187_500,
            },
        },
        {
            "name": "tcja_ex_pre_tcja_po",
            "exemption_joint": {
                2026: 109_800,
                2027: 112_100,
                2028: 114_400,
                2029: 116_700,
                2030: 119_000,
                2031: 121_300,
                2032: 123_700,
                2033: 126_200,
                2034: 128_700,
                2035: 131_200,
            },
            "exemption_other": {
                2026: 70_600,
                2027: 72_100,
                2028: 73_500,
                2029: 75_000,
                2030: 76_400,
                2031: 78_000,
                2032: 79_500,
                2033: 81_100,
                2034: 82_700,
                2035: 84_300,
            },
            "phase_out_joint": {
                2026: 1_278_575,
                2027: 1_304_475,
                2028: 1_329_675,
                2029: 1_354_850,
                2030: 1_381_475,
                2031: 1_408_825,
                2032: 1_436_875,
                2033: 1_465_650,
                2034: 1_495_150,
                2035: 1_525_375,
            },
            "phase_out_other": {
                2026: 639_300,
                2027: 652_250,
                2028: 664_825,
                2029: 677_425,
                2030: 690_725,
                2031: 704_400,
                2032: 718_425,
                2033: 732_825,
                2034: 747_575,
                2035: 762_675,
            },
        },
        {
            "name": "tcja_both",
            "exemption_joint": {
                2026: 109_800,
                2027: 112_100,
                2028: 114_400,
                2029: 116_700,
                2030: 119_000,
                2031: 121_300,
                2032: 123_700,
                2033: 126_200,
                2034: 128_700,
                2035: 131_200,
            },
            "exemption_other": {
                2026: 70_600,
                2027: 72_100,
                2028: 73_500,
                2029: 75_000,
                2030: 76_400,
                2031: 78_000,
                2032: 79_500,
                2033: 81_100,
                2034: 82_700,
                2035: 84_300,
            },
            "phase_out_joint": {
                2026: 209_000,
                2027: 213_200,
                2028: 217_400,
                2029: 221_600,
                2030: 226_000,
                2031: 230_400,
                2032: 234_800,
                2033: 239_200,
                2034: 243_600,
                2035: 248_000,
            },
            "phase_out_other": {
                2026: 156_900,
                2027: 160_200,
                2028: 163_400,
                2029: 166_700,
                2030: 170_000,
                2031: 173_300,
                2032: 176_800,
                2033: 180_300,
                2034: 183_800,
                2035: 187_500,
            },
        },
        {
            "name": "tcja_nmp",
            "amt_eliminate_marriage_penalty": True,
            "exemption_joint": {
                2026: 141_200,
                2027: 144_200,
                2028: 147_000,
                2029: 150_000,
                2030: 152_800,
                2031: 156_000,
                2032: 159_000,
                2033: 162_200,
                2034: 165_400,
                2035: 168_600,
            },
            "exemption_other": {
                2026: 70_600,
                2027: 72_100,
                2028: 73_500,
                2029: 75_000,
                2030: 76_400,
                2031: 78_000,
                2032: 79_500,
                2033: 81_100,
                2034: 82_700,
                2035: 84_300,
            },
            "phase_out_joint": {
                2026: 313_800,
                2027: 320_400,
                2028: 326_800,
                2029: 333_400,
                2030: 340_000,
                2031: 346_600,
                2032: 353_600,
                2033: 360_600,
                2034: 367_600,
                2035: 375_000,
            },
            "phase_out_other": {
                2026: 156_900,
                2027: 160_200,
                2028: 163_400,
                2029: 166_700,
                2030: 170_000,
                2031: 173_300,
                2032: 176_800,
                2033: 180_300,
                2034: 183_800,
                2035: 187_500,
            },
        },
    ]

    behavioral = [False, True]

    tcja_other_extended = [False, True]

    return list(product(salt_configs, amt_configs, behavioral, tcja_other_extended))

# %%
def get_behavioral_reform():
    """Returns the behavioral response reform parameters"""
    return {
        "gov.simulation.labor_supply_responses.elasticities.income": {
            "2024-01-01.2100-12-31": -0.05
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.1": {
            "2024-01-01.2100-12-31": 0.31
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.10": {
            "2024-01-01.2100-12-31": 0.22
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.2": {
            "2024-01-01.2100-12-31": 0.28
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.3": {
            "2024-01-01.2100-12-31": 0.27
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.4": {
            "2024-01-01.2100-12-31": 0.27
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.5": {
            "2024-01-01.2100-12-31": 0.25
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.6": {
            "2024-01-01.2100-12-31": 0.25
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.7": {
            "2024-01-01.2100-12-31": 0.22
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.8": {
            "2024-01-01.2100-12-31": 0.22
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.9": {
            "2024-01-01.2100-12-31": 0.22
        },
        "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.secondary": {
            "2024-01-01.2100-12-31": 0.27
        },
    }

# %%
def get_other_tcja_provisions():
    """Returns the reform dictionary for TCJA extension"""
    return {
        "gov.irs.credits.ctc.amount.base[0].amount": {"2026-01-01.2100-12-31": 2000},
        "gov.irs.credits.ctc.phase_out.threshold.HEAD_OF_HOUSEHOLD": {
            "2026-01-01.2100-12-31": 200000
        },
        "gov.irs.credits.ctc.phase_out.threshold.JOINT": {
            "2026-01-01.2100-12-31": 400000
        },
        "gov.irs.credits.ctc.phase_out.threshold.SEPARATE": {
            "2026-01-01.2100-12-31": 200000
        },
        "gov.irs.credits.ctc.phase_out.threshold.SINGLE": {
            "2026-01-01.2100-12-31": 200000
        },
        "gov.irs.credits.ctc.phase_out.threshold.SURVIVING_SPOUSE": {
            "2026-01-01.2100-12-31": 400000
        },
        "gov.irs.credits.ctc.refundable.individual_max": {
            "2026-01-01.2026-12-31": 1800,
            "2027-01-01.2027-12-31": 1800,
            "2028-01-01.2028-12-31": 1800,
            "2029-01-01.2029-12-31": 1900,
            "2030-01-01.2030-12-31": 1900,
            "2031-01-01.2031-12-31": 1900,
            "2032-01-01.2032-12-31": 2000,
            "2033-01-01.2033-12-31": 2000,
            "2034-01-01.2034-12-31": 2000,
            "2035-01-01.2035-12-31": 2000,
        },
        "gov.irs.credits.ctc.refundable.phase_in.threshold": {
            "2026-01-01.2100-12-31": 2500
        },
        "gov.irs.deductions.itemized.casualty.active": {"2026-01-01.2100-12-31": False},
        "gov.irs.deductions.itemized.charity.ceiling.all": {
            "2026-01-01.2100-12-31": 0.6
        },
        "gov.irs.deductions.itemized.limitation.agi_rate": {
            "2026-01-01.2100-12-31": 1,
        },
        "gov.irs.deductions.itemized.limitation.applicable_amount.HEAD_OF_HOUSEHOLD": {
            "2026-01-01.2100-12-31": 1000000,
        },
        "gov.irs.deductions.itemized.limitation.applicable_amount.JOINT": {
            "2026-01-01.2100-12-31": 1000000,
        },
        "gov.irs.deductions.itemized.limitation.applicable_amount.SEPARATE": {
            "2026-01-01.2100-12-31": 1000000,
        },
        "gov.irs.deductions.itemized.limitation.applicable_amount.SINGLE": {
            "2026-01-01.2100-12-31": 1000000,
        },
        "gov.irs.deductions.itemized.limitation.applicable_amount.SURVIVING_SPOUSE": {
            "2026-01-01.2100-12-31": 1000000,
        },
        "gov.irs.deductions.itemized.limitation.itemized_deduction_rate": {
            "2026-01-01.2100-12-31": 1,
        },
        "gov.irs.deductions.qbi.max.business_property.rate": {
            "2026-01-01.2100-12-31": 0.025
        },
        "gov.irs.deductions.qbi.max.rate": {"2026-01-01.2100-12-31": 0.2},
        "gov.irs.deductions.qbi.max.w2_wages.alt_rate": {"2026-01-01.2100-12-31": 0.25},
        "gov.irs.deductions.qbi.max.w2_wages.rate": {"2026-01-01.2100-12-31": 0.5},
        "gov.irs.deductions.qbi.phase_out.length.HEAD_OF_HOUSEHOLD": {
            "2026-01-01.
SURVIVING_SPOUSE": {
            "2026-01-01.2026-12-31": 767125,
            "2027-01-01.2027-12-31": 782650,
            "2028-01-01.2028-12-31": 797775,
            "2029-01-01.2029-12-31": 812875,
            "2030-01-01.2030-12-31": 828850,
            "2031-01-01.2031-12-31": 845250,
            "2032-01-01.2032-12-31": 862100,
            "2033-01-01.2033-12-31": 879350,
            "2034-01-01.2034-12-31": 897050,
            "2035-01-01.2035-12-31": 915200,
        },
        "gov.irs.income.exemption.amount": {"2026-01-01.2100-12-31": 0},
    }

# %%
def create_reform_dict(salt_config, amt_config, behavioral, tcja_other_extended, year):
    """Create reform dictionary with optional behavioral responses"""
    reform_dict = {}

    # SALT caps
    reform_dict.update(
        {
            "gov.irs.deductions.itemized.salt_and_real_estate.cap.JOINT": {
                "2026-01-01.2100-12-31": salt_config["cap_joint"]
            },
            "gov.irs.deductions.itemized.salt_and_real_estate.cap.SURVIVING_SPOUSE": {
                "2026-01-01.2100-12-31": salt_config["cap_joint"]
            },
            "gov.irs.deductions.itemized.salt_and_real_estate.cap.SEPARATE": {
                "2026-01-01.2100-12-31": salt_config["cap_joint"] / 2
            },
            "gov.irs.deductions.itemized.salt_and_real_estate.cap.SINGLE": {
                "2026-01-01.2100-12-31": salt_config["cap_other"]
            },
            "gov.irs.deductions.itemized.salt_and_real_estate.cap.HEAD_OF_HOUSEHOLD": {
                "2026-01-01.2100-12-31": salt_config["cap_other"]
            },
            # Phase-out parameters
            "gov.contrib.salt_phase_out.in_effect": {
                "2024-01-01.2100-12-31": salt_config["phase_out"]
            },
            # Joint rate parameters for SALT phase-out
            "gov.contrib.salt_phase_out.rate.joint[1].rate": {
                "2024-01-01.2100-12-31": salt_config["phase_out_rate"]
            },
            "gov.contrib.salt_phase_out.rate.other[1].rate": {
                "2024-01-01.2100-12-31": salt_config["phase_out_rate"]
            },
            "gov.contrib.salt_phase_out.rate.joint[1].threshold": {
                "2024-01-01.2100-12-31": salt_config["phase_out_threshold_joint"]
            },
            "gov.contrib.salt_phase_out.rate.other[1].threshold": {
                "2024-01-01.2100-12-31": salt_config["phase_out_threshold_other"]
            },
        }
    )

    # Determine the separate filer exemption and phase-out thresholds.
    # For the no marriage penalty (NMP) configuration, use the specified "other" values.
    # Otherwise, default to half of the joint values.
    if amt_config.get("amt_eliminate_marriage_penalty", False):
        separate_exemption = amt_config["exemption_other"][year]
        separate_phase_out = amt_config["phase_out_other"][year]
    else:
        separate_exemption = amt_config["exemption_joint"][year] / 2
        separate_phase_out = amt_config["phase_out_joint"][year] / 2

    # AMT parameters - use year-specific values
    reform_dict.update(
        {
            "gov.irs.income.amt.exemption.amount.JOINT": {
                f"{year}-01-01.{year}-12-31": amt_config["exemption_joint"][year]
            },
            "gov.irs.income.amt.exemption.amount.SURVIVING_SPOUSE": {
                f"{year}-01-01.{year}-12-31": amt_config["exemption_joint"][year]
            },
            "gov.irs.income.amt.exemption.amount.SEPARATE": {
                f"{year}-01-01.{year}-12-31": separate_exemption
            },
            "gov.irs.income.amt.exemption.amount.SINGLE": {
                f"{year}-01-01.{year}-12-31": amt_config["exemption_other"][year]
            },
            "gov.irs.income.amt.exemption.amount.HEAD_OF_HOUSEHOLD": {
                f"{year}-01-01.{year}-12-31": amt_config["exemption_other"][year]
            },
            # Phase-out thresholds
            "gov.irs.income.amt.exemption.phase_out.start.JOINT": {
                f"{year}-01-01.{year}-12-31": amt_config["phase_out_joint"][year]
            },
            "gov.irs.income.amt.exemption.phase_out.start.SURVIVING_SPOUSE": {
                f"{year}-01-01.{year}-12-31": amt_config["phase_out_joint"][year]
            },
            "gov.irs.income.amt.exemption.phase_out.start.SEPARATE": {
                f"{year}-01-01.{year}-12-31": separate_phase_out
            },
            "gov.irs.income.amt.exemption.phase_out.start.SINGLE": {
                f"{year}-01-01.{year}-12-31": amt_config["phase_out_other"][year]
            },
            "gov.irs.income.amt.exemption.phase_out.start.HEAD_OF_HOUSEHOLD": {
                f"{year}-01-01.{year}-12-31": amt_config["phase_out_other"][year]
            },
        }
    )

    # Add behavioral responses if enabled
    if behavioral:
        reform_dict.update(get_behavioral_reform())

    # Add TCJA extension reform if applicable
    if tcja_other_extended:
        reform_dict.update(get_other_tcja_provisions())


    # Add itemization branch
    reform_dict.update(get_itemization_branch())
    return reform_dict

# %%
def get_tcja_extension_reform():
    """Returns the reform dictionary for TCJA extension"""
    return {
        "gov.irs.credits.ctc.amount.base[0].amount": {"2026-01-01.2100-12-31": 2000},
        "gov.irs.credits.ctc.phase_out.threshold.HEAD_OF_HOUSEHOLD": {
            "2026-01-01.2100-12-31": 200000
        },
        "gov.irs.credits.ctc.phase_out.threshold.JOINT": {
            "2026-01-01.2100-12-31": 400000
        },
        "gov.irs.credits.ctc.phase_out.threshold.SEPARATE": {
            "2026-01-01.2100-12-31": 200000
        },
        "gov.irs.credits.ctc.phase_out.threshold.SINGLE": {
            "2026-01-01.2100-12-31": 200000
        },
        "gov.irs.credits.ctc.phase_out.threshold.SURVIVING_SPOUSE": {
            "2026-01-01.2100-12-31": 400000
        },
        "gov.irs.credits.ctc.refundable.individual_max": {
            "2026-01-01.2026-12-31": 1800,
            "2027-01-01.2027-12-31": 1800,
            "2028-01-01.2028-12-31": 1800,
            "2029-01-01.2029-12-31": 1900,
            "2030-01-01.2030-12-31": 1900,
            "2031-01-01.2031-12-31": 1900,
            "2032-01-01.2032-12-31": 2000,
            "2033-01-01.2033-12-31": 2000,
            "2034-01-01.2034-12-31": 2000,
            "2035-01-01.2035-12-31": 2000,
        },
        "gov.irs.credits.ctc.refundable.phase_in.threshold": {
            "2026-01-01.2100-12-31": 2500
        },
        "gov.irs.deductions.itemized.casualty.active": {"2026-01-01.2100-12-31": False},
        "gov.irs.deductions.itemized.charity.ceiling.all": {
            "2026-01-01.2100-12-31": 0.6
        },
        "gov.irs.deductions.itemized.limitation.agi_rate": {
            "2026-01-01.2100-12-31": 1,
        },
        "gov.irs.deductions.itemized.limitation.applicable_amount.HEAD_OF_HOUSEHOLD": {
            "2026-01-01.2100-12-31": 1000000,
        },
        "gov.irs.deductions.itemized.limitation.applicable_amount.JOINT": {
            "2026-01-01.2100-12-31": 1000000,
        },
        "gov.irs.deductions.itemized.limitation.applicable_amount.SEPARATE": {
            "2026-01-01.2100-12-31": 1000000,
        },
        "gov.irs.deductions.itemized.limitation.applicable_amount.SINGLE": {
            "2026-01-01.2100-12-31": 1000000,
        },
        "gov.irs.deductions.itemized.limitation.applicable_amount.SURVIVING_SPOUSE": {
            "2026-01-01.2100-12-31": 1000000,
        },
        "gov.irs.deductions.itemized.limitation.itemized_deduction_rate": {
            "2026-01-01.2100-12-31": 1,
        },
        "gov.irs.deductions.itemized.salt_and_real_estate.cap.HEAD_OF_HOUSEHOLD": {
            "2026-01-01.2100-12-31": 10000
        },
        "gov.irs.deductions.itemized.salt_and_real_estate.cap.JOINT": {
            "2026-01-01.2100-12-31": 10000
        },
        "gov.irs.deductions.itemized.salt_and_real_estate.cap.SEPARATE": {
            "2026-01-01.2100-12-31": 5000
        },
        "gov.irs.deductions.itemized.salt_and_real_estate.cap.SINGLE": {
            "2026-01-01.2100-12-31": 10000
        },
        "gov.irs.deductions.itemized.salt_and_real_estate.cap.SURVIVING_SPOUSE": {
            "2026-01-01.2100-12-31": 10000
        },
        "gov.irs.deductions.qbi.max.business_property.rate": {
            "2026-01-01.2100-12-31": 0.025
        },
        "gov.irs.deductions.qbi.max.rate": {"2026-01-01.2100-12-31": 0.2},
        "gov.irs.deductions.qbi.max.w2_wages.alt_rate": {"2026-01-01.2100-12-31": 0.25},
        "gov.irs.deductions.qbi.max.w2_wages.rate": {"2026-01-01.2100-12-31": 0.5},
        "gov.irs.deductions.qbi.phase_out.length.HEAD_OF_HOUSEHOLD": {
            "2026-01-01.2100-12-31": 50000
        },
        "gov.irs.deductions.qbi.phase_out.length.JOINT": {
            "2026-01-01.2100-12-31": 100000
        },
        "gov.irs.deductions.qbi.phase_out.length.SEPARATE": {
            "2026-01-01.2100-12-31": 50000
        },
        "gov.irs.deductions.qbi.phase_out.length.SINGLE": {
            "2026-01-01.2100-12-31": 50000
        },
        "gov.irs.deductions.qbi.phase_out.length.SURVIVING_SPOUSE": {
            "2026-01-01.2100-12-31": 100000
        },
        "gov.irs.deductions.qbi.phase_out.start.HEAD_OF_HOUSEHOLD": {
            "2024-01-01.2024-12-31": 198225,
            "2025-01-01.2025-12-31": 200275,
            "2026-01-01.2026-12-31": 204900,
            "2027-01-01.2027-12-31": 209050,
            "2028-01-01.2028-12-31": 213075,
            "2029-01-01.2029-12-31": 217125,
            "2030-01-01.2030-12-31": 221375,
            "2031-01-01.2031-12-31": 225775,
            "2032-01-01.2032-12-31": 230275,
            "2033-01-01.2033-12-31": 234875,
            "2034-01-01.2034-12-31": 239600,
            "2035-01-01.2035-12-31": 244450,
        },
        "gov.irs.deductions.qbi.phase_out.start.JOINT": {
            "2024-01-01.2024-12-31": 396450,
            "2025-01-01.2025-12-31": 400575,
            "2026-01-01.2026-12-31": 409800,
            "2027-01-01.2027-12-31": 418100,
            "2028-01-01.2028-12-31": 426175,
            "2029-01-01.2029-12-31": 434225,
            "2030-01-01.2030-12-31": 442775,
            "2031-01-01.2031-12-31": 451525,
            "2032-01-01.2032-12-31": 460525,
            "2033-01-01.2033-12-31": 469750,
            "2034-01-01.2034-12-31": 479200,
            "2035-01-01.2035-12-31": 488900,
        },
        "gov.irs.deductions.qbi.phase_out.start.SEPARATE": {
            "2024-01-01.2024-12-31": 198225,
            "2025-01-01.2025-12-31": 200275,
            "2026-01-01.2026-12-31": 204900,
            "2027-01-01.2027-12-31": 209050,
SURVIVING_SPOUSE": {
            "2026-01-01.2026-12-31": 767125,
            "2027-01-01.2027-12-31": 782650,
            "2028-01-01.2028-12-31": 797775,
            "2029-01-01.2029-12-31": 812875,
            "2030-01-01.2030-12-31": 828850,
            "2031-01-01.2031-12-31": 845250,
            "2032-01-01.2032-12-31": 862100,
            "2033-01-01.2033-12-31": 879350,
            "2034-01-01.2034-12-31": 897050,
            "2035-01-01.2035-12-31": 915200,
        },
        "gov.irs.income.exemption.amount": {"2026-01-01.2100-12-31": 0},
        # Add branching for itemization
        "gov.simulation.branch_to_determine_itemization": {
            "2026-01-01.2100-12-31": True
        }
    }

# %%
# Define the years to analyze
YEARS = range(2027, 2036)

# Define the output directory
OUTPUT_DIR = "../data/impacts_2026_2035"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
def get_baseline_data(subsampled_baseline_sim, year):
    """Get baseline income and decile data"""
    baseline_income = subsampled_baseline_sim.calculate(
        "income_tax", map_to="household", period=year
    )
    decile = subsampled_baseline_sim.calculate("household_income_decile", period=year)
    valid_indices = decile >= 0
    people = subsampled_baseline_sim.calc("household_count_people", period=year)
    net_income = subsampled_baseline_sim.calc("household_net_income", period=year)
    return {
        "income": baseline_income[valid_indices],
        "unfiltered_decile": decile,
        "decile": decile[valid_indices],
        "full_income": baseline_income,
        "people": people,
        "net_income": net_income,
    }

# %%
def load_progress(year):
    """Load existing progress for a specific year"""
    progress_file = os.path.join(OUTPUT_DIR, f"new_impacts_{year}.csv")
    if os.path.exists(progress_file):
        impacts_df = pd.read_csv(progress_file)
        impacts = impacts_df.to_dict("records")
        completed_reforms = {
            reform.replace("_vs_current_law", "").replace("_vs_current_policy", "")
            for reform in impacts_df["reform"]
        }
    else:
        # If the progress file doesn't exist, check if the year is 2026 and load from impacts.csv
        if year == 2026:
            try:
                impacts_df = pd.read_csv("../data/new_impacts.csv")
                impacts = impacts_df.to_dict("records")
                completed_reforms = {
                    reform.replace("_vs_current_law", "").replace(
                        "_vs_current_policy", ""
                    )
                    for reform in impacts_df["reform"]
                }
                # Save the 2026 data to the new progress file
                impacts_df.to_csv(progress_file, index=False)
            except FileNotFoundError:
                impacts = []
                completed_reforms = set()
        else:
            impacts = []
            completed_reforms = set()
    return impacts, completed_reforms

# %%
def calculate_metrics(reform_sim, baseline_data, year):
    """Calculate total income change."""
    # Get reform income tax (unfiltered)
    reform_tax = reform_sim.calculate("income_tax", map_to="household", period=year)
    baseline_tax = baseline_data["full_income"]

    # Calculate total tax change
    total_tax_change = reform_tax.sum() - baseline_tax.sum()

    return {
        "total_income_change": total_tax_change,
    }

# %%
def calculate_impacts_for_year(year, behavioral=False):
    """Calculate impacts for a specific year, with or without behavioral responses."""
    # Add itemization branch
    baseline_reform = Reform.from_dict(get_itemization_branch(), country_id="us")
    print(f"Calculating impacts for {year} (behavioral={behavioral})...")
    baseline_sim = Microsimulation(
        reform=baseline_reform,
        dataset="hf://policyengine/policyengine-us-data/enhanced_cps_2024.h5"
    )
    subsampled_baseline_sim = baseline_sim.subsample(frac = 0.5)
    baseline_data = get_baseline_data(subsampled_baseline_sim, str(year))
    tcja_reform = Reform.from_dict(get_tcja_extension_reform(), country_id="us")
    tcja_baseline_sim = Microsimulation(
        reform=tcja_reform,
        dataset="hf://policyengine/policyengine-us-data/enhanced_cps_2024.h5",
    )
    subsampled_tcja_baseline_sim = tcja_baseline_sim.subsample(frac = 0.5)
    tcja_baseline_data = get_baseline_data(subsampled_tcja_baseline_sim, str(year))
    impacts, completed_reforms = load_progress(year)
    combinations = generate_policy_combinations()
    combinations = [c for c in combinations if c[2] == behavioral]
    total_combinations = len(combinations)
    print(f"Processing {total_combinations} policy combinations for {year}...")

    for i, (salt_config, amt_config, _, tcja_other_extended) in enumerate(
        combinations, 1
    ):
        scenario_name = (
            f"salt_{salt_config['name']}_amt_{amt_config['name']}_"
            f"behavioral_responses{'_yes' if behavioral else '_no'}_"
            f"other_tcja_provisions_extended{'_yes' if tcja_other_extended else '_no'}_"
            f"year_{year}"
        )

        if scenario_name in completed_reforms:
            print(
                f"Skipping completed combination {i}/{total_combinations}: {scenario_name}"
            )
            continue

        # Display the current reform being computed
        print(f"Processing combination {i}/{total_combinations}: {scenario_name}")
        print(f"  SALT Config: {salt_config['name']}")
        print(f"  AMT Config: {amt_config['name']}")
        print(f"  Behavioral Responses: {'Yes' if behavioral else 'No'}")
        print(
            f"  TCJA Other Provisions Extended: {'Yes' if tcja_other_extended else 'No'}"
        )

        try:
            reform_dict = create_reform_dict(
                salt_config, amt_config, behavioral, tcja_other_extended, year
            )
            reform = Reform.from_dict(reform_dict, country_id="us")
            reformed = Microsimulation(
                reform=reform,
                dataset="hf://policyengine/policyengine-us-data/enhanced_cps_2024.h5",
            )
            subsampled_reformed = reformed.subsample(frac = 0.5)

            # Calculate metrics vs current law baseline
            current_law_metrics = calculate_metrics(subsampled_reformed, baseline_data, str(year))
            current_law_impacts = {
                "reform": f"{scenario_name}_vs_current_law",
                "baseline": "Current Law",
                "year": year,
                **current_law_metrics,
            }
            impacts.append(current_law_impacts)

            # Calculate metrics vs current policy baseline
            current_policy_metrics = calculate_metrics(
                subsampled_reformed, tcja_baseline_data, str(year)
            )
            current_policy_impacts = {
                "reform": f"{scenario_name}_vs_current_policy",
                "baseline": "Current Policy",
                "year": year,
                **current_policy_metrics,
            }
            impacts.append(current_policy_impacts)

            # Save checkpoint
            impacts_df = pd.DataFrame(impacts)
            impacts_df.to_csv(
                os.path.join(OUTPUT_DIR, f"new_impacts_{year}.csv"), index=False
            )
            completed_reforms.add(scenario_name)
            print(f"Saved checkpoint after {scenario_name}")

        except Exception as e:
            print(f"Error processing {scenario_name}: {str(e)}")
            with open(os.path.join(OUTPUT_DIR, "error_log.txt"), "a") as f:
                f.write(f"\nError on {scenario_name}: {str(e)}")
            continue

    return impacts

# %%
def calculate_impacts_for_all_years():
    """Calculate impacts for all years from 2026 to 2035."""
    all_impacts = []

    # Then, compute impacts with behavioral responses
    for year in [2035]:
        if year == 2026:
            print("Skipping 2026 (data already exists)...")
            continue  # Skip 2026 since data already exists
        impacts = calculate_impacts_for_year(year, behavioral=True)
        all_impacts.extend(impacts)


    # First, compute impacts without behavioral responses
    for year in YEARS:
        if year == 2026:
            print("Skipping 2026 (data already exists)...")
            continue  # Skip 2026 since data already exists
        impacts = calculate_impacts_for_year(year, behavioral=False)
        all_impacts.extend(impacts)




    # Save final results
    final_df = pd.DataFrame(all_impacts)
    final_df.to_csv(os.path.join(OUTPUT_DIR, "all_impacts_2026_2035.csv"), index=False)
    print("All impacts calculated and saved!")

# %%
if __name__ == "__main__":
    print("Starting tax reform impact calculations for 2026-2035...")
    calculate_impacts_for_all_years()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 if __name__ == "__main__":
#       2     print("Starting tax reform impact calculations for 2026-2035...")
# ----> 3     calculate_impacts_for_all_years()
#
# Cell In[13], line 10, in calculate_impacts_for_all_years()
#       8         print("Skipping 2026 (data already exists)...")
#       9         continue  # Skip 2026 since data already exists
# ---> 10     impacts = calculate_impacts_for_year(year, behavioral=True)
#      11     all_impacts.extend(impacts)
#      14 # First, compute impacts without behavioral responses
#
# Cell In[12], line 62, in calculate_impacts_for_year(year, behavioral)
#      59 subsampled_reformed = reformed.subsample(frac = 0.5)
#      61 # Calculate metrics vs current law baseline
# ---> 62 current_law_metrics = calculate_metrics(subsampled_reformed, baseline_data, str(year))
#      63 current_law_impacts = {
#      64     "reform": f"{scenario_name}_vs_current_law",
#      65     "baseline": "Current Law",
#      66     "year": year,
#      67     **current_law_metrics,
#      68 }
#      69 impacts.append(current_law_impacts)
#
# Cell In[11], line 4, in calculate_metrics(reform_sim, baseline_data, year)
#       2 """Calculate total income change."""
#       3 # Get reform income tax (unfiltered)
# ----> 4 reform_tax = reform_sim.calculate("income_tax", map_to="household", period=year)
#       5 baseline_tax = baseline_data["full_income"]
#       7 # Calculate total tax change
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/tax/federal_income/income_tax.py:18, in income_tax.formula(person, period, parameters)
#      16     return 0
#      17 else:
# ---> 18     added_components = add(
#      19         person, period, ["income_tax_before_refundable_credits"]
#      20     )
#      21     subtracted_components = add(
#      22         person, period, ["income_tax_refundable_credits"]
#      23     )
#      24     return added_components - subtracted_components
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/tax/federal_income/income_tax_before_refundable_credits.py:18, in income_tax_before_refundable_credits.formula(tax_unit, period, parameters)
#      16     return 0
#      17 else:
# ---> 18     added_components = add(
#      19         tax_unit,
#      20         period,
#      21         [
#      22             "income_tax_before_credits",
#      23             "net_investment_income_tax",
#      24             "recapture_of_investment_credit",
#      25             "unreported_payroll_tax",
#      26             "qualified_retirement_penalty",
#      27         ],
#      28     )
#      29     subtracted_components = add(
#      30         tax_unit, period, ["income_tax_capped_non_refundable_credits"]
#      31     )
#      32     return added_components - subtracted_components
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:932, in Simulation._run_formula(self, variable, population, period)
#     930 for added_variable in adds_list:
#     931     if added_variable in self.tax_benefit_system.variables:
# --> 932         values = values + self.calculate(
#     933             added_variable, period, map_to=variable.entity.key
#     934         )
#     935     else:
#     936         try:
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/tax/federal_income/before_credits/income_tax_main_rates.py:14, in income_tax_main_rates.formula(tax_unit, period, parameters)
#      12 def formula(tax_unit, period, parameters):
#      13     # compute taxable income that is taxed at the main rates
# ---> 14     full_taxable_income = tax_unit("taxable_income", period)
#      15     cg_exclusion = tax_unit(
#      16         "capital_gains_excluded_from_taxable_income", period
#      17     )
#      18     taxinc = max_(0, full_taxable_income - cg_exclusion)
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/taxable_income.py:12, in taxable_income.formula(tax_unit, period, parameters)
#      11 def formula(tax_unit, period, parameters):
# ---> 12     agi = tax_unit("adjusted_gross_income", period)
#      13     exemptions = tax_unit("exemptions", period)
#      14     deductions = tax_unit("taxable_income_deductions", period)
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/adjusted_gross_income/adjusted_gross_income.py:13, in adjusted_gross_income.formula(tax_unit, period, parameters)
#      12 def formula(tax_unit, period, parameters):
# ---> 13     gross_income = add(tax_unit, period, ["irs_gross_income"])
#      14     above_the_line_deductions = tax_unit(
#      15         "above_the_line_deductions", period
#      16     )
#      17     agi = gross_income - above_the_line_deductions
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:186, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
# --> 186         entity.members(variable, period, options=options)
#     187     )
#     188 elif entity.entity.is_person:
#     189     raise ValueError(
#     190         f"You requested to aggregate {variable} (defined for {variable_entity.plural}) to {entity.entity.plural}, but this is not yet implemented."
#     191     )
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/adjusted_gross_income/irs_gross_income/irs_gross_income.py:19, in irs_gross_income.formula(person, period, parameters)
#      16 not_dependent = ~person("is_tax_unit_dependent", period)
#      17 for source in sources:
#      18     # Add positive values only - losses are deducted later.
# ---> 19     total += not_dependent * max_(0, add(person, period, [source]))
#      20 return total
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/adjusted_gross_income/irs_gross_income/irs_employment_income.py:13, in irs_employment_income.formula(person, period, parameters)
#      12 def formula(person, period, parameters):
# ---> 13     employment_income = person("employment_income", period)
#      14     pre_tax_contributions = person("pre_tax_contributions", period)
#      15     return max_(0, employment_income - pre_tax_contributions)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:932, in Simulation._run_formula(self, variable, population, period)
#     930 for added_variable in adds_list:
#     931     if added_variable in self.tax_benefit_system.variables:
# --> 932         values = values + self.calculate(
#     933             added_variable, period, map_to=variable.entity.key
#     934         )
#     935     else:
#     936         try:
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/simulation/labor_supply_response/labor_supply_response.py:251, in employment_income_behavioral_response.formula(person, period, parameters)
#     250 def formula(person, period, parameters):
# --> 251     lsr = person("labor_supply_behavioral_response", period)
#     252     employment_income = person("employment_income_before_lsr", period)
#     253     self_employment_income = person(
#     254         "self_employment_income_before_lsr", period
#     255     )
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/simulation/labor_supply_response/labor_supply_response.py:223, in labor_supply_behavioral_response.formula(person, period, parameters)
#     212     branch.set_input(
#     213         "employment_income_before_lsr",
#     214         period,
#     215         person("employment_income_before_lsr", period),
#     216     )
#     217     branch.set_input(
#     218         "self_employment_income_before_lsr",
#     219         period,
#     220         person("self_employment_income_before_lsr", period),
#     221     )
# --> 223 response = add(
#     224     person,
#     225     period,
#     226     [
#     227         "income_elasticity_lsr",
#     228         "substitution_elasticity_lsr",
#     229     ],
#     230 )
#     231 simulation = person.simulation
#     232 del simulation.branches["baseline"].branches[
#     233     "baseline_lsr_measurement"
#     234 ]
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/simulation/labor_supply_response/labor_supply_response.py:85, in income_elasticity_lsr.formula(person, period, parameters)
#      81 self_employment_income = person(
#      82     "self_employment_income_before_lsr", period
#      83 )
#      84 earnings = employment_income + self_employment_income
# ---> 85 income_change = person("relative_income_change", period)
#      86 return earnings * income_change * person("income_elasticity", period)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/simulation/labor_supply_response/labor_supply_response.py:19, in relative_income_change.formula(person, period, parameters)
#      15 baseline_branch = simulation.get_branch("baseline").get_branch(
#      16     "baseline_lsr_measurement"
#      17 )
#      18 baseline_person = baseline_branch.populations["person"]
# ---> 19 baseline_net_income = baseline_person.household(
#      20     "household_net_income", period
#      21 )
#      22 measurement_person = measurement_branch.populations["person"]
#      23 net_income = measurement_person.household(
#      24     "household_net_income", period
#      25 )
#
# File ~/policyengine-core/policyengine_core/projectors/projector.py:33, in Projector.__call__(self, *args, **kwargs)
#      32 def __call__(self, *args, **kwargs):
# ---> 33     result = self.reference_entity(*args, **kwargs)
#      34     return self.transform_and_bubble_up(result)
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:932, in Simulation._run_formula(self, variable, population, period)
#     930 for added_variable in adds_list:
#     931     if added_variable in self.tax_benefit_system.variables:
# --> 932         values = values + self.calculate(
#     933             added_variable, period, map_to=variable.entity.key
#     934         )
#     935     else:
#     936         try:
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:932, in Simulation._run_formula(self, variable, population, period)
#     930 for added_variable in adds_list:
#     931     if added_variable in self.tax_benefit_system.variables:
# --> 932         values = values + self.calculate(
#     933             added_variable, period, map_to=variable.entity.key
#     934         )
#     935     else:
#     936         try:
#
#     [... skipping similar frames: Simulation._calculate at line 707 (1 times), Microsimulation.calculate at line 54 (1 times), Simulation.calculate at line 477 (1 times)]
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:932, in Simulation._run_formula(self, variable, population, period)
#     930 for added_variable in adds_list:
#     931     if added_variable in self.tax_benefit_system.variables:
# --> 932         values = values + self.calculate(
#     933             added_variable, period, map_to=variable.entity.key
#     934         )
#     935     else:
#     936         try:
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/credits/ctc/refundable/refundable_ctc.py:34, in refundable_ctc.formula(tax_unit, period, parameters)
#      31 maximum_refundable_ctc = min_(maximum_amount, total_ctc)
#      33 phase_in = tax_unit("ctc_phase_in", period)
# ---> 34 limiting_tax = tax_unit("ctc_limiting_tax_liability", period)
#      35 ctc_capped_by_tax = min_(total_ctc, limiting_tax)
#      36 ctc_capped_by_increased_tax = min_(total_ctc, limiting_tax + phase_in)
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# ...
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/deductions/tax_liability_if_not_itemizing.py:20, in tax_liability_if_not_itemizing.formula(tax_unit, period, parameters)
#      14 non_itemized_branch = simulation.get_branch("not_itemizing")
#      15 non_itemized_branch.set_input(
#      16     "tax_unit_itemizes",
#      17     period,
#      18     np.zeros((tax_unit.count,), dtype=bool),
#      19 )
# ---> 20 return non_itemized_branch.calculate(
#      21     "federal_state_income_tax", period
#      22 )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:932, in Simulation._run_formula(self, variable, population, period)
#     930 for added_variable in adds_list:
#     931     if added_variable in self.tax_benefit_system.variables:
# --> 932         values = values + self.calculate(
#     933             added_variable, period, map_to=variable.entity.key
#     934         )
#     935     else:
#     936         try:
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/tax/federal_income/income_tax.py:18, in income_tax.formula(person, period, parameters)
#      16     return 0
#      17 else:
# ---> 18     added_components = add(
#      19         person, period, ["income_tax_before_refundable_credits"]
#      20     )
#      21     subtracted_components = add(
#      22         person, period, ["income_tax_refundable_credits"]
#      23     )
#      24     return added_components - subtracted_components
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/tax/federal_income/income_tax_before_refundable_credits.py:18, in income_tax_before_refundable_credits.formula(tax_unit, period, parameters)
#      16     return 0
#      17 else:
# ---> 18     added_components = add(
#      19         tax_unit,
#      20         period,
#      21         [
#      22             "income_tax_before_credits",
#      23             "net_investment_income_tax",
#      24             "recapture_of_investment_credit",
#      25             "unreported_payroll_tax",
#      26             "qualified_retirement_penalty",
#      27         ],
#      28     )
#      29     subtracted_components = add(
#      30         tax_unit, period, ["income_tax_capped_non_refundable_credits"]
#      31     )
#      32     return added_components - subtracted_components
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/policyengine-core/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/policyengine-core/policyengine_core/populations/group_population.py:38, in GroupPopulation.__call__(self, variable_name, period, options)
#      36     return self.sum(self.members(variable_name, period, options))
#      37 else:
# ---> 38     return super().__call__(variable_name, period, options)
#
# File ~/policyengine-core/policyengine_core/populations/population.py:137, in Population.__call__(self, variable_name, period, options)
#     133     return self.simulation.calculate_divide(
#     134         variable_name, period, **calculate_kwargs
#     135     )
#     136 else:
# --> 137     return self.simulation.calculate(
#     138         variable_name, period, **calculate_kwargs
#     139     )
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:932, in Simulation._run_formula(self, variable, population, period)
#     930 for added_variable in adds_list:
#     931     if added_variable in self.tax_benefit_system.variables:
# --> 932         values = values + self.calculate(
#     933             added_variable, period, map_to=variable.entity.key
#     934         )
#     935     else:
#     936         try:
#
# File ~/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:477, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     474 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     476 try:
# --> 477     result = self._calculate(variable_name, period)
#     478     if isinstance(result, EnumArray) and decode_enums:
#     479         result = result.decode_to_str()
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:707, in Simulation._calculate(self, variable_name, period)
#     705 try:
#     706     self._check_for_cycle(variable.name, period)
# --> 707     array = self._run_formula(variable, population, period)
#     709     # If no result, use the default value and cache it
#     710     if array is None:
#     711         # Check if the variable has a previously defined value
#
# File ~/policyengine-core/policyengine_core/simulations/simulation.py:997, in Simulation._run_formula(self, variable, population, period)
#     995     array = formula(population, period)
#     996 else:
# --> 997     array = formula(population, period, parameters_at)
#     999 return array
#
# File ~/policyengine-us/policyengine_us/variables/gov/irs/tax/federal_income/before_credits/income_tax_main_rates.py:28, in income_tax_main_rates.formula(tax_unit, period, parameters)
#      26 for i in range(1, len(list(bracket_rates.__iter__())) + 1):
#      27     b = str(i)
# ---> 28     bracket_top = bracket_tops[b][filing_status]
#      29     tax += bracket_rates[b] * amount_between(
#      30         taxinc, bracket_bottom, bracket_top
#      31     )
#      32     bracket_bottom = bracket_top
#
# File ~/policyengine-core/policyengine_core/parameters/parameter_node_at_instant.py:58, in ParameterNodeAtInstant.__getitem__(self, key)
#      53 def __getitem__(
#      54     self, key: str
#      55 ) -> Union["ParameterNodeAtInstant", VectorialParameterNodeAtInstant]:
#      56     # If fancy indexing is used, cast to a vectorial node
#      57     if isinstance(key, numpy.ndarray):
# ---> 58         return parameters.VectorialParameterNodeAtInstant.build_from_node(
#      59             self
#      60         )[key]
#      61     return self._children[key]
#
# File ~/policyengine-core/policyengine_core/parameters/vectorial_parameter_node_at_instant.py:210, in VectorialParameterNodeAtInstant.__getitem__(self, key)
#     208 elif isinstance(key, EnumArray):
#     209     enum = key.possible_values
# --> 210     key = numpy.select(
#     211         [key == item.index for item in enum],
#     212         [item.name for item in enum],
#     213     )
#     214 else:
#     215     key = key.astype("str")
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/numpy/lib/function_base.py:864, in select(condlist, choicelist, default)
#     862 condlist = condlist[::-1]
#     863 for choice, cond in zip(choicelist, condlist):
# --> 864     np.copyto(result, choice, where=cond)
#     866 return result
#
# KeyboardInterrupt:
